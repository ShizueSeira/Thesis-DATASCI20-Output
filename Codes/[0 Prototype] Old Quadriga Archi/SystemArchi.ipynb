# %% [markdown]
# # Libraries and Imports needed

# %%
# Install nightly package for some functionalities that aren't in alpha
# !pip install tf-nightly-gpu-2.0-preview
# !pip install tf-hub-nightly
# !pip install tensorflow==2.0.0-alpha

# Install TF Hub for TF2
# !pip install 'tensorflow-hub == 0.5'
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tf-nightly-gpu-2.0-preview: filename=tf_nightly_gpu_2_0_preview-0.0.0.1-py3-none-any.whl size=1542 sha256=a871044b3844ba71e62979ad29d587bb086d9e7c17be90833995874183bf758e
#   Stored in directory: /root/.cache/pip/wheels/50/39/2e/a9e8955905c7218ac8015dfd4fa44450c6c2119212c464a01c
# Successfully built tf-nightly-gpu-2.0-preview
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.7/620.8 MB 2.7 MB/s eta 0:02:56
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/urllib3/response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ^^^^^^^^^^^^^^^^^^
# ...

# %%
from __future__ import absolute_import, division, print_function, unicode_literals


import tensorflow as tf
#tf.logging.set_verbosity(tf.logging.ERROR)
#tf.enable_eager_execution()

import tensorflow_hub as hub
import os
from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
#from keras import optimizers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2913344177.py in <cell line: 0>()
#       6 #tf.enable_eager_execution()
#       7
# ----> 8 import tensorflow_hub as hub
#       9 import os
#      10 from tensorflow.keras.layers import Dense, Flatten, Conv2D
#
# /usr/local/lib/python3.12/dist-packages/tensorflow_hub/__init__.py in <module>
#      27 # error message is thrown instead of an obscure error of missing
#      28 # symbols at executing the imports.
# ---> 29 from tensorflow_hub.estimator import LatestModuleExporter
#      30 from tensorflow_hub.estimator import register_module_for_export
#      31 from tensorflow_hub.feature_column import image_embedding_column
#
# /usr/local/lib/python3.12/dist-packages/tensorflow_hub/estimator.py in <module>
#      61
#      62
# ---> 63 class LatestModuleExporter(tf_v1.estimator.Exporter):
# ...

# %%
# verify TensorFlow version

print("Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("Hub version: ", hub.__version__)
print("GPU is", "available" if tf.test.is_gpu_available() else "NOT AVAILABLE")

# %% [markdown]
# # Pre-processing Module -> 1st Module or Starting Module

# %%
# A. Image Extraction
# - Extract RGB rice leaf images (PNG/JPG to numpy arrays).

# %%
# B. Pre-Processing Steps
# - Remove duplicate leaf images. (Manual or Automatic)?
# - Normalize color of leaf images. (Manual or Automatic)?
# - Annotate and label dataset.
# - Generate CSV/JSON file containing metadata and labels.

# %%
# C. Exploratory Data Analysis (EDA)
# - Perform EDA (basic statistics, class distribution, visualization).
# - Check for data imbalance.

# %%
# D. Dataset Splitting
# - Apply train_test_split or equivalent.
# Split into:
# -Training dataset (80% Bangladeshi)
# -Validation (20% Bangladeshi) + testing dataset (local dataset)
# -In-house dataset (Training + Validation + Testing, In separate Datasets prepared)

# %%
# E. Data Augmentation (test first if  w/o data augmentation feasible on time)
# - Apply Data Augmentation on the training dataset (ex : Flipping, Image Rotation, Lightning)

# %% [markdown]
# # Training Module -> 2nd Module

# %%
# A. Baseline Model
# - Implement baseline CNN model (VGG16).

# %%
# B. Feature Extraction
# - Train with VGG16.
# - Extract features using VGG16.
# - Modifying Dense Layers for Classification
# - Normalize features (using StandardScaler). (In preparation For PLSR w/ thresholding & XGBoost)

# %%
# C. Classification Models
# - Classification using PLS with Thresholding.
# - Classification using XGBoost.

# %%
# D. Evaluation
# - Evaluate each model.
# - Train selected/best-performing model.
# - Save trained model.

# %% [markdown]
# # Validation Module -> 3rd Module

# %%
# A. Model Evaluation
# - Evaluate trained model on validation set.

# %%
# B. Hyperparameter Tuning
# - Tune model parameters (e.g., learning rate, layers, optimizer, tree depth for XGBoost).

# %%
# C. Optimal Model
# - Select optimal model for deployment/testing.

# %% [markdown]
# # Testing Module -> 4th or Final Module

# %%
# A. Image Extraction
# - Run final model on the testing dataset.
# - Detect rice leaf blast presence.

# %%
# B. Pre-Processing Steps
# - Classify rice leaf images into categories (infected vs healthy).

# %%
# C. Exploratory Data Analysis (EDA)
# - Compute accuracy, precision, recall, F1-score, confusion matrix.
# - Finalize rice leaf blast classification system.
